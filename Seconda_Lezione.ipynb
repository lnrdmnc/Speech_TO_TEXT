# %% [markdown]
# <a href="https://colab.research.google.com/github/lnrdmnc/Speech_TO_TEXT/blob/main/Seconda_Lezione.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-0mwla0zd
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-0mwla0zd
#   Resolved https://github.com/openai/whisper.git to commit 25639fc17ddc013d56c594bfbf7644f2185fad84
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (2.4.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (4.66.5)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20240930) (10.5.0)
# Collecting tiktoken (from openai-whisper==20240930)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting triton>=2.0.0 (from openai-whisper==20240930)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton>=2.0.0->openai-whisper==20240930) (3.16.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20240930) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20240930) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20240930) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20240930) (2024.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20240930) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20240930) (1.3.0)
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 6.0 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.6 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20240930-py3-none-any.whl size=803321 sha256=9e65295e7d81360cf9681f1b70dde1b6c91f742302750c6d8f30ac8ed6d469d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i5f9uhbz/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: triton, tiktoken, openai-whisper
# Successfully installed openai-whisper-20240930 tiktoken-0.7.0 triton-3.0.0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,027 kB]
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,362 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,596 kB]
# Get:16 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [27.8 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,590 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,447 kB]
# Fetched 16.4 MB in 2s (7,312 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 49 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !whisper "/content/Lezione IGES -   04-03-2021.mp4" --model medium --language it
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:12<00:00, 119MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# [00:00.000 --> 00:27.560]  Allora, oggi cominciamo con parlare software maintenance e in particolare anche di software
# [00:27.560 --> 00:34.720]  evolution, definiremo un po' di tassonomia, un po' di terminologia utilizzata per software
# [00:34.720 --> 00:44.720]  maintenance and evolution. Faremo una pausa più o meno a metà della lezione, vabbè vedremo un
# [00:44.720 --> 00:56.520]  po' di modi in cui è definita software maintenance, vedremo quali sono i concetti fondamentali legati
# [00:56.520 --> 01:04.840]  alla manutenzione del software e poi parleremo di evoluzione e di manutenzione di altri tipi
# [01:04.840 --> 01:15.680]  di sistemi come sistemi basati su componenti. Il termine manutenzione è stato introdotto
# [01:15.680 --> 01:22.440]  a inizio anni 70, se pensate che l'ingegnere del software come disciplina è stato introdotto
# [01:22.440 --> 01:30.880]  alla fine degli anni 60. Il problema fondamentale dell'ingegnere del software era quella della
# [01:30.880 --> 01:40.520]  manutenzione ed evoluzione dei sistemi esistenti, cioè il problema, la necessità di avere tecniche
# [01:40.520 --> 01:48.960]  ingegneristiche per la produzione del software, era soprattutto legata al problema che la
# [01:48.960 --> 01:58.520]  manutenzione del software ormai assorbiva il grosso dello sforzo nell'ambito dello sviluppo del
# [01:58.520 --> 02:06.200]  software e quindi è chiaro che i termini sono nati praticamente in contemporanea, il vero
# [02:06.200 --> 02:14.640]  problema era questo, il fatto che non si avevano abbastanza risorse per sviluppare nuovo software,
# [02:14.640 --> 02:18.960]  infatti si parlava della crisi del software a quel tempo, quindi la crisi del software è proprio il
# [02:18.960 --> 02:26.440]  fatto che non si riesce più a produrre software nuovo perché tutto il tempo è dedicato alla
# [02:26.440 --> 02:37.760]  manutenzione, alla gestione di software che già esiste. Tenete presente che quella è un'epoca
# [02:37.760 --> 02:44.960]  in cui il software viene sviluppato in casa, non esistono ancora le software house, non esistono
# [02:44.960 --> 02:51.520]  ancora le aziende che hanno come core business la produzione del software, ma esistono aziende che
# [02:51.520 --> 02:58.400]  in qualche modo sviluppano in casa i loro sistemi software e quindi che cosa succede? Che una volta
# [02:58.400 --> 03:04.080]  sviluppati i sistemi software è quello che il tempo viene dedicato fondamentalmente a gestire
# [03:04.080 --> 03:08.040]  questi sistemi all'interno di queste aziende, quindi chiaramente non è che queste aziende
# [03:08.040 --> 03:15.960]  possono far crescere a dismisura i team di sviluppo software per andare incontro alle
# [03:15.960 --> 03:25.040]  nuove esigenze. Ecco perché poi si è passato ad un modello di produzione industriale in cui le
# [03:25.040 --> 03:32.480]  aziende dedicate allo sviluppo software facevano solo quello, quindi in qualche modo la parte di
# [03:32.480 --> 03:40.880]  sviluppo software, diciamo le divisioni di sviluppo software che erano incluse nelle diverse aziende
# [03:40.880 --> 03:48.240]  sono state via via smantellate, ridotte e mentre invece si è passata ad avere del personale che
# [03:48.240 --> 03:54.240]  si occupasse solo della gestione di questi sistemi e del rapporto chiaramente con i fornitori di
# [03:54.240 --> 04:04.880]  servizi di sviluppo e manutenzione del software. Ok, quindi diciamo negli anni 70 nasce il problema
# [04:04.880 --> 04:12.360]  di software maintenance e il problema è che il maintenance era vista proprio con una manutenzione
# [04:12.360 --> 04:17.720]  che si fa a casa, fondamentalmente corregge errori, però il problema della crisi del software non era
# [04:17.720 --> 04:22.880]  tanto quello di correggere errori ma era dovuto al fatto che c'era la esigenza di arricchire le
# [04:22.880 --> 04:29.440]  funzionalità di un sistema software, quindi questa è il grosso dello sforzo della manutenzione,
# [04:29.440 --> 04:34.760]  perché tutto sommato se noi pensiamo allo sviluppo, alla manutenzione semplicemente come
# [04:34.760 --> 04:40.080]  correzione, correggio difetti, correggio difetti, correggio difetti, a un certo punto non ci stanno
# [04:40.080 --> 04:46.520]  più difetti da correggere, ma perché nel tempo io ho bisogno sempre di correggere difetti al mio
# [04:46.520 --> 04:52.200]  sistema software? Perché io faccio anche enhancement, vado a migliorare le funzionalità del mio sistema,
# [04:52.200 --> 04:56.160]  aggiungere funzionalità, migliorare quelli esistenti, e chiaramente queste modifiche
# [04:56.160 --> 05:04.760]  introducono altri difetti e quindi continuamente vedremo se si deve anche agire con manutenzione
# [05:04.760 --> 05:20.120]  correttiva. Lo standard più aggiornato sulla manutenzione software è quello ISO-IEC-EI-EE14764,
# [05:20.120 --> 05:28.240]  è stato prodotto da una task force congiunta dell'ISO e dell'IEEE per andare a unificare in
# [05:28.240 --> 05:40.720]  qualche modo gli standard dell'ISO e lo standard dell'IEEE e allineare questo standard a quello
# [05:40.720 --> 05:44.920]  che è lo standard sui processi del ciclo di vita del software, che è anche quello che è stato prodotto
# [05:45.200 --> 05:54.840]  task force congiunta dell'ISO e dell'IEEE. Lo standard 14764 definisce software maintenance come
# [05:54.840 --> 06:01.240]  l'insieme delle attività richieste per fornire supporto costo effettivo, quindi efficace, a un
# [06:01.240 --> 06:08.040]  sistema software. Le attività sono eseguite sia durante il pre delivery stage, quindi durante già
# [06:08.040 --> 06:12.120]  lo sviluppo, quindi prima del rilascio del sistema, sia dopo il rilascio del sistema,
# [06:12.120 --> 06:19.800]  quindi post delivery stage. Chiaramente le attività di pre delivery stage sono fondamentalmente
# [06:19.800 --> 06:28.960]  attività di pianificazione di quelle che saranno poi le attività condotte durante il post delivery
# [06:28.960 --> 06:42.480]  stage. Una visione di software maintenance, una classificazione è quella intention based,
# [06:42.480 --> 06:46.800]  che significa intention based, cioè che cosa io voglio andare a fare quando faccio manutenzione.
# [06:46.800 --> 06:52.600]  Quindi le attività di manutenzione possono essere divise in quattro gruppi, corrective maintenance,
# [06:52.600 --> 07:03.480]  lo scopo è quello di correggere failures, che possono essere failure di elaborazione,
# [07:03.480 --> 07:08.960]  quindi failure legate a requisiti funzionali, quindi al mancato soddisfacimento di requisiti
# [07:08.960 --> 07:16.320]  funzionali e performance failures, cioè failure legate al mancato rispetto di requisiti non
# [07:16.320 --> 07:25.200]  funzionali. Ma adaptive maintenance invece è un tipo di manutenzione che viene applicata quando
# [07:25.200 --> 07:36.360]  io voglio fare in modo che il sistema sia adatti ai cambiamenti dell'ambiente in cui viene utilizzato,
# [07:36.360 --> 07:46.160]  quindi sia il contesto sia l'ambiente fisico in termini di piattaforma hardware
# [07:46.160 --> 07:53.080]  software su cui il sistema viene eseguito. Quindi io posso adattare a una nuova piattaforma
# [07:53.080 --> 08:01.280]  hardware software, ma posso anche adattare il sistema a dei cambiamenti all'interno dell'ambiente
# [08:01.280 --> 08:07.680]  operativo in cui il sistema viene eseguito, quindi cambiamenti nell'ambito di leggi o di
# [08:07.680 --> 08:15.320]  regolamentazioni che in qualche modo spingono poi il sistema a cambiare, ad adattarsi. Pensate
# [08:15.320 --> 08:24.800]  ad esempio alla manutenzione anno 2000 o alla manutenzione euro, non abbiamo parlato di questo
# [08:24.800 --> 08:31.520]  tipo di manutenzione, però dovete immaginare che il passaggio dalla lira all'euro è stato un passaggio
# [08:31.520 --> 08:46.920]  che voi non avete probabilmente conosciuto, ma eravate troppo piccoli per capire che cosa stava
# [08:46.920 --> 08:54.480]  succedendo, ma il passaggio dalla lira all'euro è stato un tipo di intervento di manutenzione di
# [08:54.480 --> 09:08.520]  tipo massivo, cioè fatto a tappeto su tutti i sistemi software e un tipo di manutenzione che
# [09:08.520 --> 09:16.240]  ovviamente doveva modificare la valuta. Quindi considerate che ci sono state diverse fasi,
# [09:16.240 --> 09:27.360]  c'è stata la fase in cui la valuta era mantenuta in lire, però doveva avere anche la valuta in
# [09:27.360 --> 09:39.840]  euro. Un'altra fase in cui la valuta era mantenuta in euro, però bisognava avere anche il
# [09:39.840 --> 09:46.960]  corrispondente e dire fino a quando la valuta nazionale è stata completamente eliminata.
# [09:46.960 --> 09:54.320]  Quindi ci sono state tutte queste diverse fasi che hanno accompagnato il percorso di introduzione
# [09:54.320 --> 10:00.160]  dell'euro, quindi è durato diversi anni questo passaggio con le varie fasi. E chiaramente questo
# [10:00.160 --> 10:10.200]  è un tipo di manutenzione attiva, ma la stessa manutenzione anno 2000 può essere considerata
# [10:10.200 --> 10:22.040]  come manutenzione attiva, perché se prima il contesto era un contesto in cui le date andavano
# [10:22.040 --> 10:31.240]  dal 1999, adesso il contesto è cambiato, il sistema va utilizzato in un contesto in cui le
# [10:31.240 --> 10:39.320]  date possono andare anche oltre il 2000 e quindi questo ha richiesto un cambiamento del sistema.
# [10:39.320 --> 10:46.320]  Non può essere definita come una manutenzione correttiva, perché in realtà io non sto
# [10:46.320 --> 10:55.880]  correggendo un bug. Il fatto che la data era memorizzata con due anni era dovuto ad un'assunzione
# [10:55.880 --> 11:03.280]  implicita che era stata fatta da parte degli sviluppatori e di chi aveva richiesto il sviluppo
# [11:03.280 --> 11:10.600]  di questi sistemi e che questi sistemi dovessero non sopravvivere al cambiamento di secolo. Nel
# [11:10.600 --> 11:13.840]  momento in cui cambia il contesto, cioè i sistemi devono sopravvivere al cambiamento di secolo,
# [11:14.360 --> 11:23.680]  va adattato il sistema al nuovo contesto. Perfective maintenance lo scopo è quello
# [11:23.680 --> 11:31.720]  di migliorare il sistema e poi essere usabilità, possono essere anche le funzionalità, possono
# [11:31.720 --> 11:41.360]  essere migliorate, l'efficienza, la manutenibilità e infine preventive maintenance. Allora la prima
# [11:41.400 --> 11:46.640]  versione dello standard IEEE classificava la manutenzione soltanto in queste tre categorie.
# [11:46.640 --> 11:58.120]  Poi è nato il termine preventive maintenance che in qualche modo ha a che fare con interventi
# [11:58.120 --> 12:05.000]  che vogliono prevenire problemi prima che si verifichino che cosa significa. Preventive
# [12:05.000 --> 12:13.920]  maintenance in pratica è un particolare tipo di manutenzione che mira a correggere dei problemi.
# [12:13.920 --> 12:22.160]  Quindi a differenza di corrective maintenance che è un tipo di manutenzione reattiva, nel momento
# [12:22.160 --> 12:34.920]  in cui l'utente ha esperienza di una failure, notifica questa failure al team di supporto.
# [12:34.920 --> 12:41.400]  E il team di supporto deve capire perché si è verificata una failure e se una failure che
# [12:41.400 --> 12:50.440]  richiede un intervento da parte di sviluppatori, questa notifica viene inoltrata di sviluppatori
# [12:50.440 --> 12:57.000]  che dovranno andare a correggere il problema e quindi poi fare tutti i testing di regressione
# [12:57.000 --> 13:03.000]  e così via. Preventive maintenance invece è fatto prima, io so che possono esserci delle failure,
# [13:03.240 --> 13:10.200]  però non sono stato ancora capace di individuare, quindi cerco di battere sul tempo l'utente e
# [13:10.200 --> 13:15.760]  quindi andare a individuare i difetti che potrebbero causare dei malfunziamenti prima
# [13:15.760 --> 13:24.080]  che questi si verifichino durante l'esercizio del sistema e quindi andare a correggere questi
# [13:24.080 --> 13:29.960]  problemi. In alcuni, diciamo in letteratura, alcuni autori hanno usato il termine preventive
# [13:30.040 --> 13:38.080]  maintenance per fare riferimento a interventi di re-engineering o ristrutturazione di sistemi per
# [13:38.080 --> 13:46.120]  migliorare la manutenibilità e quindi ridurre i costi poi di manutenzione. Però poi nello standard
# [13:46.120 --> 13:53.240]  IEEE e ISO, così come nel software engineering body of knowledge, preventive maintenance fa
# [13:53.240 --> 14:00.880]  riferimento appunto a interventi correttivi, interventi correttivi fatti in maniera preventiva.
# [14:00.880 --> 14:17.400]  Sono Emilio Schiavo, però purtroppo non ho la webcam collegata in questo momento,
# [14:17.400 --> 14:27.860]  volevo chiederle se le attività in seguito ad un penetration testing possano essere fatte
# [14:27.860 --> 14:33.320]  delle attività di manutenzione, anche queste rientrano in attività di preventive maintenance?
# [14:33.320 --> 14:47.400]  Allora, quando parlo di maintenance è qualcosa che io sto facendo durante l'esercizio del sistema,
# [14:47.400 --> 15:01.760]  ok? Quindi fondamentalmente sono attività che io faccio per prevenire l'insorgere di
# [15:01.760 --> 15:06.680]  malfunzionamenti. Nel caso che dice lei se faccio penetration testing io sto facendo testing,
# [15:06.680 --> 15:13.440]  quindi sto in fase di sviluppo, non sto in fase di manutenzione. Eh vabbè, penetration testing si
# [15:13.440 --> 15:19.080]  potrebbe fare però anche in una fase post deploy. Potrei farlo in una fase post delivery, vuol dire
# [15:19.080 --> 15:27.160]  che continuo a fare testing perché diciamo il problema è che io so che possono esserci dei
# [15:27.160 --> 15:36.040]  problemi, ok? E allora potrei continuarlo a fare, scopro dei problemi e cerco di risolverli prima
# [15:36.040 --> 15:40.840]  che questi si verifichino in esercizio. Certo, cioè se è qualcosa che io faccio, se è un'attività
# [15:40.840 --> 15:50.200]  che io faccio durante il post delivery, non in maniera reattiva rispetto a quello che diciamo mi
# [15:50.200 --> 15:56.400]  comunica, mi notifica l'utente riguardo i malfunzionamenti del sistema, ma in maniera preventiva,
# [15:56.400 --> 16:02.480]  cioè l'attività che faccio di mia sponte per andare a prevenire l'insorgere di questi problemi,
# [16:02.480 --> 16:08.400]  è chiaro questo rientra nell'ambito di attività di manutenzione preventiva, ok? La ringrazio.
# [16:08.400 --> 16:18.880]  Perché anche diciamo correggere difetti di sicurezza sono comunque legati a difetti
# [16:18.880 --> 16:25.640]  a non rispondenza di requisiti non funzionali. Se io avevo un requisito non funzionale che mi
# [16:25.640 --> 16:30.800]  diceva che doveva avere certe caratteristiche di sicurezza e quel sistema non le fornisce,
# [16:30.800 --> 16:36.880]  e allora è chiaro che quello è un difetto e prima o poi questo difetto si rivelerà con un
# [16:36.880 --> 16:48.360]  malfunzionamento. Ok, grazie. Ok, corrective maintenance, quindi lo scopo di corrective
# [16:49.360 --> 16:57.760]  malfunzionamenti. Esempi, un programma che produce un cattivo output, un esempio di failure di
# [16:57.760 --> 17:04.800]  elaborazione, ma anche un programma che non è capace di rispettare requisiti di performance
# [17:04.800 --> 17:12.120]  temporali è un esempio di performance failure, così come un programma che non è capace di
# [17:12.120 --> 17:23.320]  rispettare requisiti di sicurezza. Quindi il processo di corrective maintenance è praticamente
# [17:23.320 --> 17:29.760]  molto simile a quello che fate quando fate debugging, no? Ovviamente richiede un'attività
# [17:29.760 --> 17:41.960]  di debugging. Fondamentalmente come funziona? Mi arriva il report sull'anomalia,
# [17:41.960 --> 17:49.760]  sul problema che è stato riscontrato. Molto spesso per fare questo si mettono in piedi dei
# [17:49.760 --> 18:03.320]  sistemi di ticketing, ok? So se sapete che cos'è. Viene descritto l'anomalia. È la stessa cosa che
# [18:03.320 --> 18:07.480]  capi quando voglio segnalare un problema in amministrazione, apro un ticket e poi questo
# [18:07.480 --> 18:12.800]  deve essere elaborato. Quindi io potrei, diciamo, aprire questo ticket e spiegare,
# [18:12.800 --> 18:17.400]  nel ticket, quel cosa dovrebbe fare l'utente, spiegare come si è verificata l'anomalia,
# [18:17.400 --> 18:23.840]  quindi qual è lo scenario in cui si è verificata l'anomalia, ok? Perché questo? Perché in questo
# [18:23.840 --> 18:31.520]  modo questa informazione può servire poi allo sviluppatore per replicare l'anomalia, ok? Perché
# [18:31.520 --> 18:36.320]  io, diciamo, lo sviluppatore, io non sto facendo testing, cioè qual è la differenza? Che se io
# [18:36.320 --> 18:41.640]  sto facendo testing, so qual è il caso di test che ho eseguito, lo scenario di test che ho eseguito,
# [18:41.640 --> 18:46.760]  lo conosco, giusto? Quindi su quello scenario di test si è verificato un malfunzionamento.
# [18:46.760 --> 18:51.960]  Si è verificato un malfunzionamento e io faccio debugging per andare a capire dove è il difetto
# [18:51.960 --> 19:04.400]  che causa quel malfunzionamento, ok? Ci siamo? Sì, sì. Quindi questo lo possono fare lo
# [19:04.400 --> 19:10.600]  sviluppatore, quindi sa dov'è. Ma se il problema lo rileva l'utente, come fa lo sviluppatore a
# [19:10.600 --> 19:16.640]  sapere che è successo? Come è successo? E perché? Quindi come fa a replicare? Per poter replicare
# [19:16.640 --> 19:24.200]  ha bisogno di informazioni. Perché ad esempio quando va in crash un'applicazione vi si apre
# [19:24.200 --> 19:31.600]  il formato di segnalazione? Perché nel formato di segnalazione vuoi spiegare la situazione in cui
# [19:31.600 --> 19:41.040]  si è verificato il crash, ok? E quella è un'informazione che può essere utile allo
# [19:41.040 --> 19:46.480]  sviluppatore per replicare quel crash e capire esattamente che cosa è successo e dove andare
# [19:46.480 --> 20:03.840]  a poter intervenire, ok? Per rimuovere il difetto, per correggere il difetto. E quindi
# [20:03.840 --> 20:07.800]  quello che deve fare il processo di correct maintenance è andare a individuare e isolare
# [20:07.800 --> 20:15.640]  i componenti software in cui ci sono questi difetti che devono essere rimossi. Quindi
# [20:15.640 --> 20:25.320]  correct maintenance è un processo reattivo che significa che viene messo in piedi dopo che è
# [20:25.320 --> 20:33.040]  stato individuato il mal funzionamento da parte dell'utente e quindi ha bisogno di una segnalazione
# [20:33.040 --> 20:43.840]  di un anomaly report che possa in qualche modo andare a far partire il processo. Quindi come
# [20:43.840 --> 20:47.480]  tutti i processi viene aperto il ticket e il ticket viene chiuso quando il problema viene
# [20:47.480 --> 20:55.680]  risolto. Quindi questo ticket attraverso diverse fasi, diversi attori, dall'help desk viene poi
# [20:55.680 --> 21:03.240]  inviato, viene smistrato al team che si occupa di quella parte del sistema e quindi che poi deve
# [21:03.240 --> 21:14.880]  andare a capire che cosa è successo e correggere il difetto. Quindi voi non pensate che il ticket
# [21:14.880 --> 21:23.240]  arriva direttamente allo sviluppatore? Cioè c'è un help desk, un team di supporto che si interfaccia
# [21:23.240 --> 21:29.440]  con gli utenti e questo è il team che va a chiudere l'anomalia perché questo team si occupa
# [21:29.440 --> 21:36.960]  della gestione dell'anomalia, ok? E che è un processo quello di gestire l'anomalia,
# [21:36.960 --> 21:42.400]  cioè gestire quindi dire io poi a chi devo smistare questa questa anomalia, quindi qual è
# [21:42.400 --> 21:49.200]  il team che lo deve risolvere. E quando l'anomalia viene smistata al team che deve risolvere il
# [21:49.200 --> 21:54.680]  problema si apre il vero e proprio processo di manutenzione perché questo team dovrà fare
# [21:55.680 --> 22:02.440]  il problema, progettare la modifica, rifare il test del sistema, quindi ovviamente questo si
# [22:02.440 --> 22:06.960]  interfaccia anche col configuration management perché deve andare a mettere le mani su delle
# [22:06.960 --> 22:12.200]  componenti che costituiscono una base del sistema che è in esercizio. Quindi devo produrre una nuova
# [22:12.200 --> 22:18.000]  base, la modifica deve essere approvata alla fine e deve essere rimessa in esercizio la nuova
# [22:18.000 --> 22:22.160]  versione del sistema. Quindi tutto questo è un altro processo, quindi c'è il processo di gestione
# [22:22.160 --> 22:27.200]  l'anomalia. Quindi quando vi ho rimesso in esercizio questo feedback viene inviato al team di supporto
# [22:27.200 --> 22:34.840]  che andrà poi a chiudere l'anomalia, ok? Ma vedete ci sono almeno tre processi, cioè la gestione
# [22:34.840 --> 22:41.440]  l'anomalia, il processo di manutenzione e il processo di configuration management che vengono
# [22:41.440 --> 22:49.560]  diciamo coinvolti quando viene fatto un intervento di manutenzione correttiva come questo, chiaro?
# [22:52.960 --> 22:59.040]  Poi adaptive maintenance invece, qual è lo scopo di adaptive maintenance? È quello di fare in modo
# [22:59.040 --> 23:08.680]  che il sistema sia adatto ai cambiamenti all'interno del suo ambiente, dei dati o di elaborazione e
# [23:08.680 --> 23:17.960]  quindi il software viene modificato per interfacciarsi con un ambiente in cambiamento che cambia. Allora,
# [23:17.960 --> 23:26.720]  tenete presente che se c'è un rapporto fra fornitore e cliente, cioè bisogna distinguere
# [23:26.720 --> 23:37.320]  due modi di fare manutenzione. Uno è il cliente è il proprietario del software e il software viene,
# [23:37.320 --> 23:43.720]  io diciamo, il cliente paga a un fornitore del servizio di manutenzione la gestione dell'esercizio
# [23:44.080 --> 23:50.240]  della manutenzione del sistema. Quindi cosa farà l'azienda fornitrice? Metterà in piedi un help desk
# [23:50.240 --> 23:58.840]  presso il cliente, ok? Quindi che è quello che si interfaccia con gli utenti, a cui arrivano
# [23:58.840 --> 24:05.640]  tutte le problematiche scontrate dall'utente e quindi c'è questa parte qui che semplicemente
# [24:05.640 --> 24:12.360]  serve a mantenere il sistema in esercizio. Per mantenere il sistema in esercizio ovviamente
# [24:12.360 --> 24:18.680]  vanno corretti i difetti, per caso in cui si verificano dei malfunzionamenti. Alcuni
# [24:18.680 --> 24:25.800]  difetti potrebbero anche non arrivare al team di manutenzione, perché magari non richiedono
# [24:25.800 --> 24:31.240]  modifica del codice, ma richiedono soltanto di, chissà, c'è stato un crash a causa di un problema
# [24:31.240 --> 24:44.480]  del variale corrente, è andato giù il sistema di alimentazione e quindi magari si è creata
# [24:44.480 --> 24:48.640]  un'inconsistenza nei dati. Quindi questa può essere anche ripristinata, ma non c'è bisogno
# [24:48.640 --> 24:55.320]  di andare a modificare il codice e di creare una nuova baseline del sistema. Quindi ci sono
# [24:55.320 --> 25:00.080]  interventi che non richiedono modifica al codice e quindi possono essere fatte da un altro livello
# [25:00.440 --> 25:06.840]  di supporto, quindi a parte oltre all'herpedesk. Se invece le modifiche richiedono l'intervento
# [25:06.840 --> 25:12.080]  degli sviluppatori, allora si passa agli sviluppatori. Quindi tutto questo processo
# [25:12.080 --> 25:18.760]  serve a mantenere il sistema in esercizio, cioè a fare in modo che l'operatività del sistema sia
# [25:18.760 --> 25:27.680]  garantita. Di solito in questi contratti al massimo vengono inclusi piccoli adattamenti,
# [25:27.680 --> 25:34.760]  ma non cose sostanziali. Ad esempio un intervento di manutenzione al 92000 non può essere, diciamo,
# [25:34.760 --> 25:44.040]  o di euro, o un intervento di migrazione verso un'app, diciamo, dell'interfaccia del sistema.
# [25:44.040 --> 25:49.520]  Non può essere oggetto di un contratto di manutenzione che serve a mantenere l'esercizio
# [25:49.520 --> 25:56.960]  del sistema, ok? Ma è un contratto a parte, cioè un progetto a parte. Chiaro che molto spesso va
# [25:56.960 --> 26:01.160]  in parallelo con quello di gestione dell'esercizio del sistema. Quindi ad esempio se io devo fare
# [26:01.160 --> 26:07.280]  il porting di un'applicazione su un altro sistema operativo, un'altra architettura hardware e software,
# [26:07.280 --> 26:14.400]  non è che può essere incluso all'interno del progetto del processo e del contratto di manutenzione
# [26:14.400 --> 26:20.920]  per l'esercizio correttiva e per mantenere l'esercizio del sistema. Chiaro questo?
# [26:27.400 --> 26:33.720]  Chiaro. Quindi, quando parlo di correttamente, non dovete tenere in conto che l'azienda ha un
# [26:33.720 --> 26:40.280]  contratto di manutenzione annuale o pluriannale con un'altra azienda che gli garantisce l'esercizio,
# [26:40.280 --> 26:48.360]  che gli garantisce che il sistema funziona, ok? Poi se ci sono cambiamenti che richiedono altri
# [26:48.360 --> 26:53.160]  tipi di modifici, quindi aggiunti di funzionalità adattamente e così via, questo diventa molto
# [26:53.320 --> 26:59.040]  spesso oggetto di un nuovo contratto ad hoc, quindi a meno che non si tratta di piccole cose che
# [26:59.040 --> 27:03.000]  possono rientrare all'interno del contratto annuale. Quindi bisogna mettere in piedi un altro progetto.
# [27:03.000 --> 27:08.040]  E chiaramente i due progetti vanno in parallelo, cioè quando è stato fatto il progetto di migrazione
# [27:08.040 --> 27:13.520]  anno 2000 non è che i sistemi non venivano mantenuti in esercizio, i sistemi venivano
# [27:13.520 --> 27:17.560]  mantenuti in esercizio, c'era un contratto che legava un fornitore del servizio di manutenzione
# [27:18.000 --> 27:24.800]  all'azienda, ok? Poi magari la migrazione anno 2000 poteva essere stata affidata alla
# [27:24.800 --> 27:30.240]  stessa azienda, per una questione di semplicità, di gestione, piuttosto che ad un'altra azienda.
# [27:30.240 --> 27:40.200]  Però dovete tenere presente che i due processi andavano sincronizzati, ad esempio nel caso
# [27:40.200 --> 27:45.840]  della migrazione anno 2000 del portafoglio applicativo della Deutsche Bank, lì è stato
# [27:45.840 --> 27:52.440]  usato un processo incrementale di manutenzione anno 2000, cioè il senso che si cercava innanzitutto
# [27:52.440 --> 27:57.560]  di decomporre il sistema in tanti pacchetti, dove ogni pacchetto era abbastanza indipendente
# [27:57.560 --> 28:05.160]  dall'altro. Si procedeva ad intervenire su un pacchetto e a fare tutti gli interventi
# [28:05.160 --> 28:12.600]  per adattare quel sistema anno 2000. Quindi in questo modo si poteva anche parallelizzare
# [28:12.600 --> 28:17.400]  perché io potevo avere più sedi che si occupavano di questo, ad ogni sedi mandavo una parte
# [28:17.400 --> 28:24.400]  dei pacchetti e ogni sede faceva la manutenzione anno 2000 su questa parte dei pacchetti, ok?
# [28:24.400 --> 28:31.680]  Ovviamente che succedeva, che succede se mentre io sto facendo una conversione anno 2000 su
# [28:31.680 --> 28:37.900]  un pacchetto, il codice di quel pacchetto che è in manutenzione ordinaria correttiva
# [28:38.180 --> 28:47.180]  viene modificata a causa di malfunzionamento. Mi troverò che il pacchetto manutenzione
# [28:47.180 --> 28:53.180]  anno 2000 non è stato corretto, giusto? Quindi se lo rimetti in esercizio io reintroduco
# [28:53.180 --> 29:02.180]  un difetto che avevo eliminato, ok? Quindi che cosa succedeva? Ecco perché la sincronizzazione,
# [29:02.260 --> 29:05.460]  nel momento in cui ho fatto la manutenzione anno 2000, prima di rilasciare il sistema
# [29:05.780 --> 29:12.780]  devo replicare tutti gli interventi di manutenzione correttiva fatti su quella parte del sistema
# [29:12.900 --> 29:17.900]  all'interno del pacchetto migrato, cioè il pacchetto che è stato già adattato all'anno
# [29:17.900 --> 29:24.660]  2000 e poi rimetterlo in esercizio in modo tale da non perdere gli interventi di manutenzione
# [29:24.660 --> 29:29.260]  correttiva fatti e quindi evitare che l'utente si trovi un'altra volta a avere esperienza
# [29:29.260 --> 29:36.260]  con lo stesso tipo di malfunzionamento sul sistema adattato all'anno 2000, chiaro? Quindi
# [29:38.140 --> 29:42.020]  un processo incrementale di questo tipo è stato utile, uno per paralizzare, due per
# [29:42.020 --> 29:47.020]  ridurre diciamo il numero di interventi che bisognava replicare nel tempo, perché se
# [29:47.020 --> 29:52.020]  io faccio tutta la migrazione anno 2000 poi devo replicare gli interventi di manutenzione
# [29:52.020 --> 29:57.620]  correttiva fatti in un anno sulla parte nuova e quindi questo chiaramente può comportare
# [29:57.740 --> 30:03.740]  un allungamento dei tempi e non si finisce più, invece riducendo i pacchetti all'osso
# [30:03.740 --> 30:10.740]  io ogni pacchetto che modifico lo mando in esercizio dopo che ho aggiunto anche le modifiche
# [30:10.740 --> 30:17.740]  di manutenzione correttiva, chiaro? Quindi esempi di manutenzione adattativa sono cambiare
# [30:19.220 --> 30:25.220]  il sistema per supportare nuove configurazioni hardware, convertire il sistema da batch online,
# [30:25.740 --> 30:29.600]  esempio se ho un sistema batch lo trasformo in un sistema interattivo, oppure cambiare
# [30:29.600 --> 30:34.100]  il sistema per renderlo compatibile con altre applicazioni, tutti questi interventi sono
# [30:34.100 --> 30:41.100]  interventi di manutenzione adattiva. Perfectivementr anzi invece lo scopo è quello di avere una
# [30:43.820 --> 30:49.820]  varietà di miglioramenti come user experience, elaborazione, efficienza, manutenibilità,
# [30:49.820 --> 30:56.660]  semplici sono rendere gli output più legibili per una migliore usabilità, oppure rendere
# [30:56.660 --> 31:03.660]  l'applicazione più efficiente, oppure ristrutturare il sistema per migliorare la legibilità,
# [31:04.380 --> 31:11.380]  quindi per migliorare la manutenibilità. Quindi anche il reengineering se vogliamo è un intervento
# [31:12.380 --> 31:19.380]  di manutenzione adattiva, anche il reverse engineering, documentare il sistema è un intervento
# [31:25.660 --> 31:32.660]  di manutenzione perfettiva. Preventivementr anzi lo scopo di preventivementr anzi prevenire
# [31:32.660 --> 31:39.660]  problemi prima che si verificano, quindi uno dovrebbe andare oltre, identificare rischi
# [31:46.940 --> 31:52.820]  futuri, problemi che non conosciamo ancora, per mettere in piedi attività di manutenzione
# [31:52.820 --> 31:58.340]  preventiva vuol dire che io devo andare a investigare, cercare di capire. Alcuni problemi
# [31:58.340 --> 32:03.980]  possono essere noti perché magari ho rilasciato il sistema sapendo che c'erano dei problemi,
# [32:03.980 --> 32:10.980]  e allora prima di ricevere troppe chiamate all'helpdesk, troppi ticchetti all'helpdesk,
# [32:11.140 --> 32:17.980]  cerco di risolverli per fare in modo che l'utente non se ne accorge nemmeno, però molti altri
# [32:17.980 --> 32:24.980]  sono sconosciuti, quindi io devo in qualche modo fare un tipo di analisi del sistema,
# [32:25.660 --> 32:31.300]  di analisi del sistema, che in qualche modo va a simulare quello che può essere il comportamento
# [32:31.300 --> 32:38.300]  dell'utente per fare in modo che certe cose le scopro prima io. Quindi ovviamente un tipo
# [32:45.740 --> 32:51.180]  di attività che richiede anche un certo sforzo per mettere in campo. Non ho detto una cosa,
# [32:51.180 --> 32:58.180]  che cosa succede invece per i sistemi che non sono, cioè non c'è un rapporto cliente-fornitore,
# [33:00.980 --> 33:07.980]  ma io sto sviluppando un prodotto e devo andare a fare degli interventi sul mio prodotto,
# [33:09.940 --> 33:15.500]  cioè come faccio a fare lo scheduling degli interventi, cioè nel caso in cui c'è il cliente-fornitore
# [33:15.500 --> 33:20.180]  il cliente ha un'esigenza, quindi un'esigenza è mantenere gli esercizi, quindi faccio un
# [33:20.180 --> 33:26.220]  contratto di esercizio e manutenzione correttiva, fondamentalmente correttiva di un sistema
# [33:26.220 --> 33:31.300]  per garantirne l'esercizio. Poi se ho altre esigenze faccio altri progetti, quindi faccio
# [33:31.300 --> 33:38.300]  altri contratti per migliorare il mio sistema o per adattarlo a contesti nuovi. Ma che cosa
# [33:41.860 --> 33:48.860]  faccio se invece io ho un prodotto secondo voi? Se io ho un prodotto secondo voi, se
# [33:50.460 --> 33:57.460]  io ho un prodotto secondo voi, se ho un prodotto secondo voi, me lo faccio? Già. Magiriamo
# [34:00.880 --> 34:07.880]  che sto sviluppando Microsoft Office, come avviene la manutenzione di prodotti di questo
# [34:10.740 --> 34:17.420]  tipo? Attraverso la consulenza oraria ad esempio. La consulenza oraria si. Chi sviluppa Microsoft
# [34:17.420 --> 34:21.980]  di Microsoft Office. Cioè la Microsoft fa lo sviluppo, la manutenzione e l'evoluzione
# [34:21.980 --> 34:28.660]  della Suite Office, ma come fa a decidere come fare gli interventi di Microsoft? Ovviamente
# [34:28.660 --> 34:35.940]  qui ha molto più senso manutenzione preventiva, perché quando io rilascio, perché manutenzione
# [34:35.940 --> 34:42.540]  preventiva il fornitore, cioè chi fa manutenzione, deve mettere in campo dello sforzo. Ora,
# [34:42.540 --> 34:49.540]  a meno che nel contratto non mi venga detto fai manutenzione preventiva, ovviamente questo
# [34:49.540 --> 34:53.740]  ha un costo, la manutenzione preventiva chi fornisce il servizio di manutenzione non la
# [34:53.740 --> 35:00.340]  farà, farà la manutenzione correttiva, quando succede mi chiamo e lo faccio. Invece la manutenzione
# [35:00.340 --> 35:04.740]  preventiva ha molto più senso in contesti in cui appunto io sviluppo un prodotto per
# [35:04.740 --> 35:14.900]  il mercato, perché non sempre io ricevo segnalazioni. Quante volte voi quando si va in crash l'applicazione
# [35:14.900 --> 35:21.900]  e si apre il form, voi comprate il form e mandate la segnalazione? Penso quasi mai.
# [35:21.900 --> 35:28.300]  E allora diciamo che potrebbero ricevere delle segnalazioni, ma potrebbero anche non ricevere,
# [35:28.300 --> 35:33.540]  quindi fare l'intervento di manutenzione preventiva è opportuno perché appunto in
# [35:33.540 --> 35:37.220]  questo modo io vado ad esplorare problemi che possono verificarsi, quindi poi vengono
# [35:37.220 --> 35:38.020]  mandate le patch.
